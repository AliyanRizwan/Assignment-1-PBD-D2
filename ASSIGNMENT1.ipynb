# %% [markdown]
# # ASSIGNMENT 1 PBD

# %% [markdown]
# # PART 1

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot
import numpy as np
df = pd.read_csv('jsrt_metadata.csv')
print("Number of Patient of Each Disease=-\n")
print(df['diagnosis'].value_counts())
df['diagnosis'].value_counts().max()
mx = df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan,mx,inplace =True)
plt.pyplot.title('Total Number of Patients of each Disease')
plt.pyplot.ylabel('No of Patients')
plt.pyplot.xlabel('Diseases')
plt.pyplot.hist(df['diagnosis'], color = 'yellow',ec='black')
# Out:
# Number of Patient of Each Disease=-
#
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# susp. hamartoma                                    1
# metastasis of uterine cancer                       1
# organizing pneumonia                               1
# metastasis of ovarian cancer                       1
# metastatic lung cancer                             1
# lung canceror metastasis                           1
# pneumonia                                          1
# calcified granuloma                                1
# lung cancer(adenosquamous carcinoma)               1
# lung cancer(small cell carcinoma)                  1
# susp.tuberculoma                                   1
# organiging pneumonia                               1
# susp. sclerosing hemangioma                        1
# susp. lung metastasis                              1
# Name: diagnosis, dtype: int64
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # PART 2

# %%
df.replace("non-nodule",np.nan,inplace = True)
df.replace("benign",np.nan,inplace = True)
df.dropna(subset = ["state"], inplace=True) 
plt.pyplot.title('Total Number of Patients of each Disease (Malignant)')
plt.pyplot.pie(df['diagnosis'].value_counts(),autopct = '%1.1f%%' , labels = ['lung cancer','lung cancer(adenocarcinoma)','lung cancer(bronchioloalveolar cell carcinoma)','metastasis of colon cancer','lung cancer(squamous cell carcinoma)','lung cancer(small cell carcinoma) ','lung canceror metastasis','lung cancer(adenosquamous carcinoma)','lung cancer(large cell carcinoma)','metastatic lung cancer','metastasis of ovarian cancer','etastasis of uterine cancer','susp. lung metastasis'] )
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7e66f8ee0>,
#   <matplotlib.patches.Wedge at 0x1c7e6706790>,
#   <matplotlib.patches.Wedge at 0x1c7e6706eb0>,
#   <matplotlib.patches.Wedge at 0x1c7e670e610>,
#   <matplotlib.patches.Wedge at 0x1c7e670ed30>,
#   <matplotlib.patches.Wedge at 0x1c7e671c490>,
#   <matplotlib.patches.Wedge at 0x1c7e671cbe0>,
#   <matplotlib.patches.Wedge at 0x1c7e672b340>,
#   <matplotlib.patches.Wedge at 0x1c7e672ba60>,
#   <matplotlib.patches.Wedge at 0x1c7e67371c0>,
#   <matplotlib.patches.Wedge at 0x1c7e66d8d30>,
#   <matplotlib.patches.Wedge at 0x1c7e6737fd0>,
#   <matplotlib.patches.Wedge at 0x1c7e6746730>],
#  [Text(-0.20611945413751356, 1.080515974257694, 'lung cancer'),
#   Text(-0.4993895221842246, -0.9801071906340714, 'lung cancer(adenocarcinoma)'),
#   Text(0.4993895910074166, -0.980107155566903, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(0.8018655204790329, -0.7530017842388489, 'metastasis of colon cancer'),
#   Text(0.9287607392982477, -0.5894094409985072, 'lung cancer(squamous cell carcinoma)'),
#   Text(0.9801071935563351, -0.4993895164489588, 'lung cancer(small cell carcinoma) '),
#   Text(1.009530102465836, -0.4368626468528968, 'lung canceror metastasis'),
#   Text(1.0349688574493843, -0.3726116800503119, 'lung cancer(adenosquamous carcinoma)'),
#   Text(1.0563230633674077, -0.3068901852423695, 'lung cancer(large cell carcinoma)'),
#   Text(1.0735084449287227, -0.2399575351321897, 'metastatic lung cancer'),
#   Text(1.0864571792865916, -0.17207788229933355, 'metastasis of ovarian cancer'),
#   Text(1.0951181637045018, -0.10351911671029705, 'etastasis of uterine cancer'),
#   Text(1.099457217235311, -0.0345518084792481, 'susp. lung metastasis')],
#  [Text(-0.11242879316591647, 0.5893723495951058, '56.0%'),
#   Text(-0.27239428482775885, -0.5346039221640388, '23.0%'),
#   Text(0.27239432236768174, -0.5346039030364924, '7.0%'),
#   Text(0.43738119298856337, -0.41072824594846297, '4.0%'),
#   Text(0.5065967668899531, -0.3214960587264584, '2.0%'),
#   Text(0.5346039237580009, -0.27239428169943203, '1.0%'),
#   Text(0.5506527831631832, -0.2382887164652164, '1.0%'),
#   Text(0.5645284676996641, -0.20324273457289738, '1.0%'),
#   Text(0.5761762163822223, -0.1673946464958379, '1.0%'),
#   Text(0.5855500608702122, -0.13088592825392165, '1.0%'),
#   Text(0.5926130068835953, -0.09386066307236374, '1.0%'),
#   Text(0.5973371802024555, -0.05646497275107111, '1.0%'),
#   Text(0.5997039366738058, -0.01884644098868078, '1.0%')])

# %%
df = pd.read_csv('jsrt_metadata.csv')
df.replace("malignant",np.nan,inplace = True)
df.dropna(subset = ["state"], inplace=True) 
plt.pyplot.title('Total Number of Patients of each Disease (Benign)')
plt.pyplot.pie(df['diagnosis'].value_counts(),autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7e6521d00>,
#   <matplotlib.patches.Wedge at 0x1c7e652f610>,
#   <matplotlib.patches.Wedge at 0x1c7e652fd30>,
#   <matplotlib.patches.Wedge at 0x1c7e653c490>,
#   <matplotlib.patches.Wedge at 0x1c7e653cbb0>,
#   <matplotlib.patches.Wedge at 0x1c7e6547310>,
#   <matplotlib.patches.Wedge at 0x1c7e6547a30>,
#   <matplotlib.patches.Wedge at 0x1c7e6556190>,
#   <matplotlib.patches.Wedge at 0x1c7e65568b0>,
#   <matplotlib.patches.Wedge at 0x1c7e6556fd0>,
#   <matplotlib.patches.Wedge at 0x1c7e64fe700>,
#   <matplotlib.patches.Wedge at 0x1c7e6563e20>,
#   <matplotlib.patches.Wedge at 0x1c7e6570580>,
#   <matplotlib.patches.Wedge at 0x1c7e6570ca0>,
#   <matplotlib.patches.Wedge at 0x1c7e6580400>,
#   <matplotlib.patches.Wedge at 0x1c7e6580b20>,
#   <matplotlib.patches.Wedge at 0x1c7e658b280>,
#   <matplotlib.patches.Wedge at 0x1c7e658b9a0>,
#   <matplotlib.patches.Wedge at 0x1c7e659a100>],
#  [Text(0.7548658155281622, 0.8001109926422726, ''),
#   Text(-0.5499999702695112, 0.9526279613277877, ''),
#   Text(-1.0336618730799265, 0.3762221845411275, ''),
#   Text(-1.092562196394516, -0.12770218091164717, ''),
#   Text(-0.9526279548909482, -0.5499999814184447, ''),
#   Text(-0.7548658155281625, -0.8001109926422724, ''),
#   Text(-0.5500000148652441, -0.9526279355804297, ''),
#   Text(-0.3154835705989096, -1.053788459171082, ''),
#   Text(-0.06395932512941892, -1.0981389733221336, ''),
#   Text(0.19101298416420198, -1.083288530300532, ''),
#   Text(0.4356877338869101, -1.010037721345341, ''),
#   Text(0.6568744447537894, -0.8823355165861799, ''),
#   Text(0.8001110014767274, -0.7548658061641874, ''),
#   Text(0.8823355088985513, -0.6568744550800667, ''),
#   Text(0.9526279420172691, -0.5500000037163117, ''),
#   Text(1.0100377162463374, -0.4356877457077295, ''),
#   Text(1.0537884628632945, -0.3154835582660607, ''),
#   Text(1.0832885280650408, -0.19101299684230177, ''),
#   Text(1.0981389740706715, -0.06395931227751976, '')],
#  [Text(0.4117449902880884, 0.4364241778048759, '25.9%'),
#   Text(-0.29999998378336973, 0.5196152516333387, '14.8%'),
#   Text(-0.5638155671345053, 0.20521210065879678, '7.4%'),
#   Text(-0.5959430162151905, -0.06965573504271663, '7.4%'),
#   Text(-0.5196152481223354, -0.2999999898646062, '5.6%'),
#   Text(-0.4117449902880886, -0.4364241778048758, '3.7%'),
#   Text(-0.30000000810831495, -0.5196152375893253, '3.7%'),
#   Text(-0.1720819475994052, -0.5747937050024083, '3.7%'),
#   Text(-0.03488690461604668, -0.5989848945393456, '3.7%'),
#   Text(0.10418890045320107, -0.5908846528911992, '3.7%'),
#   Text(0.2376478548474055, -0.5509296661883678, '3.7%'),
#   Text(0.3582951516838851, -0.48127391813791626, '3.7%'),
#   Text(0.43642418262366944, -0.4117449851804658, '1.9%'),
#   Text(0.4812739139446643, -0.3582951573164, '1.9%'),
#   Text(0.5196152411003285, -0.3000000020270791, '1.9%'),
#   Text(0.5509296634070932, -0.23764786129512516, '1.9%'),
#   Text(0.5747937070163425, -0.17208194087239673, '1.9%'),
#   Text(0.5908846516718405, -0.10418890736852823, '1.9%'),
#   Text(0.598984894947639, -0.03488689760591987, '1.9%')])

# %% [markdown]
# # PART 3

# %%
df.replace("Female",np.nan,inplace = True)
df.dropna(subset = ["gender"], inplace=True) 
plt.pyplot.title('Total Number of Patients of each Disease (Male)')
plt.pyplot.pie(df['diagnosis'].value_counts(),autopct = '%1.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7e684fca0>,
#   <matplotlib.patches.Wedge at 0x1c7e685d5b0>,
#   <matplotlib.patches.Wedge at 0x1c7e685dcd0>,
#   <matplotlib.patches.Wedge at 0x1c7e686b430>,
#   <matplotlib.patches.Wedge at 0x1c7e686bb50>,
#   <matplotlib.patches.Wedge at 0x1c7e68782b0>,
#   <matplotlib.patches.Wedge at 0x1c7e68789d0>,
#   <matplotlib.patches.Wedge at 0x1c7e6885130>],
#  [Text(-0.29147957975199507, 1.060678864966961, ''),
#   Text(-0.44997566133910516, -1.0037539061953558, ''),
#   Text(0.4499753089207403, -1.0037540641819014, ''),
#   Text(0.792573596193537, -0.7627759137629114, ''),
#   Text(0.9455264473440002, -0.5621207498154055, ''),
#   Text(1.0202526058330408, -0.4111990032707889, ''),
#   Text(1.071064909745597, -0.25063910132231143, ''),
#   Text(1.0967723618330336, -0.0842044317075378, '')],
#  [Text(-0.15898886168290638, 0.5785521081637968, '58.5%'),
#   Text(-0.24544126982133005, -0.5475021306520121, '19.5%'),
#   Text(0.24544107759313102, -0.5475022168264916, '7.3%'),
#   Text(0.4323128706510201, -0.41605958932522435, '4.9%'),
#   Text(0.5157416985512727, -0.30661131808113024, '2.4%'),
#   Text(0.5565014213634767, -0.2242903654204303, '2.4%'),
#   Text(0.5842172234975984, -0.13671223708489713, '2.4%'),
#   Text(0.5982394700907455, -0.04592969002229334, '2.4%')])

# %%
df = pd.read_csv('jsrt_metadata.csv')
df.replace("Male",np.nan,inplace = True)
df.dropna(subset = ["gender"], inplace=True) 
plt.pyplot.title('Total Number of Patients of each Disease (Female)')
plt.pyplot.pie(df['diagnosis'].value_counts(),autopct = '%1.1f%%' )
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7e78a2070>,
#   <matplotlib.patches.Wedge at 0x1c7e78a2970>,
#   <matplotlib.patches.Wedge at 0x1c7e78ad0d0>,
#   <matplotlib.patches.Wedge at 0x1c7e78ad7f0>,
#   <matplotlib.patches.Wedge at 0x1c7e78adf10>,
#   <matplotlib.patches.Wedge at 0x1c7e78bb670>,
#   <matplotlib.patches.Wedge at 0x1c7e78bbd90>,
#   <matplotlib.patches.Wedge at 0x1c7e78c94f0>,
#   <matplotlib.patches.Wedge at 0x1c7e78c9c10>,
#   <matplotlib.patches.Wedge at 0x1c7e78d4370>,
#   <matplotlib.patches.Wedge at 0x1c7e689ea30>,
#   <matplotlib.patches.Wedge at 0x1c7e78e51c0>,
#   <matplotlib.patches.Wedge at 0x1c7e78e58e0>,
#   <matplotlib.patches.Wedge at 0x1c7e78e5fd0>,
#   <matplotlib.patches.Wedge at 0x1c7e78f2760>,
#   <matplotlib.patches.Wedge at 0x1c7e78f2e80>,
#   <matplotlib.patches.Wedge at 0x1c7e78fc5e0>,
#   <matplotlib.patches.Wedge at 0x1c7e78fcd00>,
#   <matplotlib.patches.Wedge at 0x1c7e790c460>,
#   <matplotlib.patches.Wedge at 0x1c7e790cb80>,
#   <matplotlib.patches.Wedge at 0x1c7e79192e0>,
#   <matplotlib.patches.Wedge at 0x1c7e7919a00>,
#   <matplotlib.patches.Wedge at 0x1c7e7926160>],
#  [Text(0.43021519694781973, 1.0123808000526031, ''),
#   Text(-1.0642320588877474, 0.2782267507547504, ''),
#   Text(-0.9782763852629417, -0.5029665138325539, ''),
#   Text(-0.7634816449169498, -0.791893792042158, ''),
#   Text(-0.5029665939762924, -0.9782763440582051, ''),
#   Text(-0.2391732299600993, -1.0736834571094285, ''),
#   Text(-0.0401742573765565, -1.099266132037298, ''),
#   Text(0.12030829677815015, -1.0934010763330813, ''),
#   Text(0.278226688479377, -1.0642320751686636, ''),
#   Text(0.4302151614030951, -1.0123808151574727, ''),
#   Text(0.5730343451478485, -0.938952415876852, ''),
#   Text(0.7036402967903138, -0.8455118761630964, ''),
#   Text(0.7918937965098022, -0.7634816402830471, ''),
#   Text(0.8455118308708978, -0.7036403512145553, ''),
#   Text(0.8946186938178392, -0.6400448364541843, ''),
#   Text(0.9389523789915485, -0.5730344055867078, ''),
#   Text(0.9782763470014005, -0.5029665882517401, ''),
#   Text(1.0123807874652109, -0.4302152265684229, ''),
#   Text(1.0410837384383926, -0.3551684805259902, ''),
#   Text(1.0642320572596558, -0.2782267569822875, ''),
#   Text(1.081702237633358, -0.19980057331996356, ''),
#   Text(1.0934010685890272, -0.12030836715862281, ''),
#   Text(1.0992661318022114, -0.040174263809102426, '')],
#  [Text(0.23466283469881075, 0.5522077091196017, '37.2%'),
#   Text(-0.5804902139387713, 0.1517600458662275, '17.4%'),
#   Text(-0.5336053010525136, -0.274345371181393, '5.8%'),
#   Text(-0.41644453359106354, -0.43194206838663163, '4.7%'),
#   Text(-0.27434541489615943, -0.5336052785772027, '4.7%'),
#   Text(-0.1304581254327814, -0.5856455220596881, '3.5%'),
#   Text(-0.021913231296303542, -0.5995997083839807, '2.3%'),
#   Text(0.06562270733353644, -0.5964005870907716, '2.3%'),
#   Text(0.15176001189784197, -0.580490222819271, '2.3%'),
#   Text(0.23466281531077912, -0.5522077173586214, '2.3%'),
#   Text(0.3125641882624628, -0.5121558632055555, '2.3%'),
#   Text(0.3838037982492621, -0.4611882960889616, '2.3%'),
#   Text(0.4319420708235284, -0.41644453106348017, '1.2%'),
#   Text(0.461188271384126, -0.3838038279352119, '1.2%'),
#   Text(0.4879738329915486, -0.34911536533864596, '1.2%'),
#   Text(0.5121558430862991, -0.3125642212291133, '1.2%'),
#   Text(0.533605280182582, -0.2743454117736764, '1.2%'),
#   Text(0.5522077022537514, -0.2346628508555034, '1.2%'),
#   Text(0.5678638573300323, -0.19372826210508554, '1.2%'),
#   Text(0.5804902130507212, -0.15176004926306588, '1.2%'),
#   Text(0.590019402345468, -0.1089821309017983, '1.2%'),
#   Text(0.596400582866742, -0.06562274572288516, '1.2%'),
#   Text(0.5995997082557516, -0.02191323480496496, '1.2%')])
